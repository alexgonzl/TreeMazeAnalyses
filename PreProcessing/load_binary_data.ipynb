# %%
import numpy as np
import time
import pandas as pd
from pathlib import Path
import sys
import json
import datetime
from pre_process_neuralynx import *
from robust_stats import *
# %matplotlib inline

import matplotlib.pyplot as plt

# %%
dataPath = Path('/scratch/users/alexg8/Data/Li/Li_OF_060118_Results/')

# %%
ch = 3
data = np.fromfile(str(dataPath/('tt_{}.bin'.format(ch))),dtype=np.int16)

# %%
data2=data.reshape(-1,4)

# %%
print(data[0:4])
plt.plot(data2[0:100,2])
plt.plot(data[0:400:4])
# Out:
# [ -5  -5 -11  -1]
